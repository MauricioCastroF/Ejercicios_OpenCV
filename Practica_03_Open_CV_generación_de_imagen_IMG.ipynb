# %% [markdown]
# <a href="https://colab.research.google.com/github/MauricioCastroF/Ejercicios_OpenCV/blob/main/Practica_03_Open_CV_generaci%C3%B3n_de_imagen_IMG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread("/content/drive/Othercomputers/Mi PC/D:/2025/2_Febrero/DAEG analisis CV/02022025_7a/fotograma/fg1.png", 0)

# %%
plt.imshow(img)
plt.show()

# %%
img2 = cv2.imread("/content/drive/Othercomputers/Mi PC/D:/2025/2_Febrero/DAEG analisis CV/02022025_7a/fotograma/fg1.png", 1) #3 canales 3 matrices

# %%
plt.imshow(img2)
plt.show()

# %%
tama = img.shape
tama2 = img2.shape

# %%
tipo = img.dtype
tipo2 = img2.dtype

# %%
print("Tamaño Gray | Tipo", tama, tipo)
# Out:
# Tamaño Gray | Tipo (2160, 3840) uint8

# %%
print("Tamaño Gray Img2 | Tipo", tama2, tipo)
# Out:
# Tamaño Gray Img2 | Tipo (2160, 3840, 3) uint8

# %%
img3 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img3)
plt.show()
